# %%
# !pip3 install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.9.9)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import csv
import psycopg2
from psycopg2 import extras

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/9a/b0/dd2b60f2dd90fbc21d1d3129c36a453c322d7995d5e3589f5b3c59ee528d/matplotlib-3.8.2-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading matplotlib-3.8.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/f3/9e/8fb3f53144269d3fecdd8786d3a4686eeff55b9b35a3c0772a3f62f71e36/contourpy-1.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading contourpy-1.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/48/a6/59dc64f3fabc9267de712256aa5337edb3aa96e245192f3d16599adaa015/fonttools-4.46.0-cp312-cp312-macosx_10_9_universal2.whl.metadata
#   Downloading fonttools-4.46.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 8.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/26/61/58bb691f6880588be3a4801d199bd776032ece07203faf3e4a8b377f7d9b/kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/3d/6f/6f716f16bcb9bf39f54b9d2d993f535a0ee42cc0fec973c80839b0720ca2/Pillow-10.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading Pillow-10.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp312-cp312-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 75.2 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.2.0-cp312-cp312-macosx_11_0_arm64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.6/242.6 kB 21.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.46.0-cp312-cp312-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 76.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 13.1 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp312-cp312-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.6 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 18.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.46.0 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.1.0 pyparsing-3.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import psycopg2
import matplotlib.pyplot as plt
from psycopg2 import extras

# %%
db_params = {
    "dbname": "finalproject",
    "user": "postgres",
    "password": "123",
    "host": "localhost" }

# %%
# Path to CSV file 
csv_file_path =  '/Users/christine/Downloads/german_air_fare.csv'

# %%
import pandas as pd
filename = "/Users/christine/Downloads/german_air_fare.csv"
df = pd.read_csv(filename)

# %%
conn_url = "postgresql://postgres:123@localhost/finalproject"
engine = create_engine(conn_url)
connection = engine.connect()

# %%
conn = psycopg2.connect(**db_params)
cur = conn.cursor()

# %%
# Function to extract city names
def extract_city_names(city_col):
    city_df = df[city_col].drop_duplicates().reset_index(drop=True)
    city_df = city_df.str.extract(r'(\w{3})\s+(.*)')
    city_df.columns = ['short_name', 'long_name']
    return city_df

# %%
# extract city names from both departure and arrival cities
departure_cities = extract_city_names('departure_city')
arrival_cities = extract_city_names('arrival_city')

# Combining and removing duplicates
cityname_df = pd.concat([departure_cities, arrival_cities]).drop_duplicates().reset_index(drop=True)
cityname_df['cityname_id'] = range(1, len(cityname_df) + 1)

cityname_df.head()
# Out:
#   short_name          long_name  cityname_id
# 0        TXL  Berlin-Tegel                 1
# 1        BRE  Bremen                       2
# 2        DTM  Dortmund                     3
# 3        DRS  Dresden                      4
# 4        DUS  Düsseldorf                   5

# %%
#insert the data into cityname table
cityname_df.to_sql('cityname', engine, if_exists='append', index=False)
engine.dispose()

# %%
# Extract the relevant columns
airplanetime_df = df[['departure_time', 'arrival_time']]

# Drop duplicates if necessary
airplanetime_df = airplanetime_df.drop_duplicates()

# Generate unique IDs
airplanetime_df['airplanetime_id'] = range(1, len(airplanetime_df) + 1)

# Reorder columns to match the table structure
airplanetime_df = airplanetime_df[['airplanetime_id', 'departure_time', 'arrival_time']]

# Display the first few rows to verify
print(airplanetime_df.head())
# Out:
#    airplanetime_id departure_time arrival_time
# 0                1         6:30am       7:45am
# 1                2         6:40am       7:55am
# 2                3         6:45am       8:00am
# 3                4         6:15am       7:30am
# 4                5         6:55am       8:10am

# %%
#insert the data into airplane table
airplanetime_df.to_sql('airplanetime', engine, if_exists='append', index=False)

engine.dispose()

# %%
# Extract unique airline names
unique_airlines = df['airline'].unique()

# Create a new DataFrame for airlines
airlines_df = pd.DataFrame(unique_airlines, columns=['name'])

# Assign unique IDs
airlines_df['airline_id'] = range(1, len(airlines_df) + 1)

# Reorder columns to match the table structure
airlines_df = airlines_df[['airline_id', 'name']]

# Display the DataFrame
print(airlines_df.head())
# Out:
#    airline_id                 name
# 0           1            Eurowings
# 1           2              easyJet
# 2           3            Lufthansa
# 3           4           Air France
# 4           5  LOT-Polish Airlines

# %%
# Insert data into the 'airlines' table
airlines_df.to_sql('airlines', engine, if_exists='append', index=False)

# Close the connection
engine.dispose()

# %%
# Extracting necessary columns and creating a copy
airfares_df = df[['departure_city', 'arrival_city', 'airline', 'stops', 'price (€)', 'departure_date', 'departure_time', 'arrival_time']].copy()

# Convert departure date into departure month and day
airfares_df['departure_date'] = pd.to_datetime(airfares_df['departure_date'], dayfirst=True)
airfares_df['departure_month'] = airfares_df['departure_date'].dt.month
airfares_df['departure_day'] = airfares_df['departure_date'].dt.day

# Drop the original departure date column if no longer needed
airfares_df = airfares_df.drop(columns=['departure_date'])

# %%
# Convert month and day to integer type
airfares_df['departure_month'] = airfares_df['departure_month'].astype('Int64')
airfares_df['departure_day'] = airfares_df['departure_day'].astype('Int64')

# %%
airfares_df['departure_city_code'] = airfares_df['departure_city'].str[:3]
airfares_df['arrival_city_code'] = airfares_df['arrival_city'].str[:3]

# %%
# Merge to get the cityname_id for departure cities
airfares_df = airfares_df.merge(cityname_df, left_on='departure_city_code', right_on='short_name', how='left')
# Assign unique IDs to each airfare
airfares_df['airfare_id'] = range(1, len(airfares_df) + 1)

# %%
print(airfares_df.head())
# Out:
#           departure_city           arrival_city    airline   stops price (€)  \
# 0  TXL Berlin-Tegel       DUS Düsseldorf         Eurowings  direct        74
# 1  TXL Berlin-Tegel       DUS Düsseldorf           easyJet  direct        75
# 2  TXL Berlin-Tegel       DUS Düsseldorf           easyJet  direct        80
# 3  TXL Berlin-Tegel       DUS Düsseldorf         Eurowings  direct        84
# 4  TXL Berlin-Tegel       DUS Düsseldorf         Eurowings  direct        84
#
#   departure_time arrival_time  departure_month  departure_day  \
# 0         6:30am       7:45am               10             25
# 1         6:40am       7:55am               10             25
# 2         6:45am       8:00am               10             25
# 3         6:15am       7:30am               10             25
# 4         6:55am       8:10am               10             25
#
#   departure_city_code arrival_city_code short_name          long_name  \
# 0                 TXL               DUS        TXL  Berlin-Tegel
# 1                 TXL               DUS        TXL  Berlin-Tegel
# 2                 TXL               DUS        TXL  Berlin-Tegel
# 3                 TXL               DUS        TXL  Berlin-Tegel
# 4                 TXL               DUS        TXL  Berlin-Tegel
#
#    cityname_id  airfare_id
# 0            1           1
# 1            1           2
# 2            1           3
# 3            1           4
# 4            1           5

# %%
# Drop the departure city code and short_name columns, keep cityname_id as is
airfares_df.drop(columns=['departure_city_code', 'arrival_city_code','short_name','long_name'], inplace=True)

# %%
# Merge to get the airline_id for each airline name in airfares_df
airfares_df = airfares_df.merge(airlines_df, left_on='airline', right_on='name', how='left')

# Drop 
airfares_df.drop(columns=['airline'], inplace=True)

# %%
# Merge to get the airplanetime_id for each combination of departure and arrival times in airfares_df
airfares_df = airfares_df.merge(airplanetime_df, on=['departure_time', 'arrival_time'], how='left')

# After merging, airfares_df will have the airplanetime_id column
# You can drop the original time columns if they are no longer needed
airfares_df.drop(columns=['departure_time', 'arrival_time'], inplace=True)

# %%
# Rename 'price (€)' column to 'price'
airfares_df.rename(columns={'price (€)': 'price'}, inplace=True)
airfares_df.rename(columns={'name': 'airline'}, inplace=True)

# %%
# Convert 'price' from string to numeric format (if needed)
airfares_df['price'] = airfares_df['price'].replace(',', '', regex=True).astype(float)

# %%
airfares_df = airfares_df[airfares_df['price'] <= 9999.99]

# %%
# Display the updated DataFrame
print(airfares_df.head())
# Out:
#           departure_city           arrival_city   stops  price  \
# 0  TXL Berlin-Tegel       DUS Düsseldorf         direct   74.0
# 1  TXL Berlin-Tegel       DUS Düsseldorf         direct   75.0
# 2  TXL Berlin-Tegel       DUS Düsseldorf         direct   80.0
# 3  TXL Berlin-Tegel       DUS Düsseldorf         direct   84.0
# 4  TXL Berlin-Tegel       DUS Düsseldorf         direct   84.0
#
#    departure_month  departure_day  cityname_id  airfare_id  airline_id  \
# 0               10             25            1           1           1
# 1               10             25            1           2           2
# 2               10             25            1           3           2
# 3               10             25            1           4           1
# 4               10             25            1           5           1
#
#      airline  airplanetime_id
# 0  Eurowings                1
# 1    easyJet                2
# 2    easyJet                3
# 3  Eurowings                4
# 4  Eurowings                5

# %%
#insert the table
airfares_df.to_sql('airfares', engine, if_exists='append', index=False)
engine.dispose()

# %%
import csv
import psycopg2

# %%
# Path to CSV file 
csv_file_path =  '/Users/christine/Downloads/germany_car_rental.csv'

# %%
conn = psycopg2.connect(**db_params)
cur = conn.cursor()

# %%
def insert_data(carrentalprice_id, drive_away_price, price):
    try:
        cur.execute(
            "INSERT INTO carrentalprice (carrentalprice_id, drive_away_price, price) VALUES (%s, %s, %s)",
            (carrentalprice_id, drive_away_price, price)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data: {e}")
        conn.rollback()

# %%
# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    carrentalprice_id = 1  # Start ID from 1
    for row in reader:
        # Convert drive_away_price and price to float, handling any empty strings
        drive_away_price = float(row['drive_away_price']) if row['drive_away_price'] else 0.0
        price = float(row['price']) if row['price'] else 0.0

        # Insert data into carrentalprice
        insert_data(carrentalprice_id, drive_away_price, price)
        
        carrentalprice_id += 1  # Increment ID for the next row

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM carrentalprice LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, Decimal('52.21'), Decimal('52.21'))
# (2, Decimal('56.67'), Decimal('56.67'))
# (3, Decimal('50.45'), Decimal('50.45'))
# (4, Decimal('58.44'), Decimal('58.44'))
# (5, Decimal('67.04'), Decimal('67.04'))

# %%
# Function to insert data into carrental
def insert_into_carrental(carrental_id, city_name, car_type):
    try:
        cur.execute(
            "INSERT INTO carrental (carrental_id, city_name, car_type) VALUES (%s, %s, %s)",
            (carrental_id, city_name, car_type)
        )
        conn.commit()
    except Exception as e:
        print(f"Error: {e}")
        conn.rollback()

# Loop through DataFrame and insert data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    carrental_id = 1  # Start ID from 1
    for row in reader:
        insert_into_carrental(
            carrental_id,
            row['city'], 
            row['product_name']
        )
        carrental_id += 1  # Increment ID for the next row

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM carrental LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, 'Frankfurt', None, None, 'Volkswagen Polo')
# (2, 'Frankfurt', None, None, 'Citroen C3 Aircross')
# (3, 'Frankfurt', None, None, 'Fiat 500')
# (4, 'Frankfurt', None, None, 'Peugeot 308')
# (5, 'Frankfurt', None, None, 'Citroen DS3')

# %%
# we have some syntax errors here, we have more codes, please keep scrolling down
#Function to insert data into the carrentalratings table
def insert_carrentalratings(carrentalrating_id, average_rating, average_text, cleanliness, condition, dropoff_time, efficiency, location, pickup_time, value_for_money):
    try:
        # Replace empty values with zeros for numeric columns
        if not average_rating:
            average_rating = 0
        if not cleanliness:
            cleanliness = 0
        if not condition:
            condition = 0
        if not dropoff_time:
            dropoff_time = 0
        if not efficiency:
            efficiency = 0
        if not value_for_money:
            value_for_money = 0

        cur.execute(
            "INSERT INTO carrentalratings (carrentalrating_id, average_rating, average_text, cleanliness, condition, dropoff_time, efficiency, location, pickup_time, value_for_money) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
            (
                carrentalrating_id, average_rating, average_text, cleanliness, condition,
                dropoff_time, efficiency, location, pickup_time, value_for_money
            )
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into carrentalratings: {e}")
        conn.rollback()


# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    carrentalrating_id = 1  # Start ID from 1
    for row in reader:
        # Extract data from the CSV file
        average_rating = row['average']
        average_text = row['average_text']
        cleanliness = row['cleanliness']
        condition = row['condition']
        dropoff_time = row['dropoff_time']
        efficiency = row['efficiency']
        location = row['location']
        pickup_time = row['pickup_time']
        value_for_money = row['value_for_money']

        # Insert data into carrentalratings
        insert_carrentalratings(
            carrentalrating_id, average_rating, average_text, cleanliness, condition,
            dropoff_time, efficiency, location, pickup_time, value_for_money
        )
        
        carrentalrating_id += 1  # Increment ID for the next row
# Out:
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (411, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (412, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (413, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (414, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (415, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (416, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (417, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (418, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (419, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (420, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (421, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (422, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (423, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (424, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (425, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (426, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (427, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (428, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (429, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (430, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (431, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (432, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (433, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (434, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (435, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (436, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (437, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (438, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (439, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (440, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (441, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (442, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (443, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (444, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (445, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (446, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (447, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (448, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (449, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (450, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (451, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (452, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (453, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (454, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (455, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (456, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (457, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (458, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (459, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (460, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (461, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (462, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (463, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (464, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (465, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (466, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (467, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (468, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (469, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (470, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (471, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (472, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (473, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (474, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (475, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (476, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (477, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (478, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (479, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (480, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (481, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (482, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (483, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (484, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (485, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (486, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (487, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (488, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (489, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (490, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (491, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (492, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (493, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (494, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (495, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (496, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (497, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (498, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (499, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (500, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (501, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (502, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (503, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (504, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (505, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (506, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (507, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (508, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (509, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (510, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (511, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (512, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (513, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (514, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (515, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (516, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (517, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (518, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (519, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (520, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (521, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (522, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (523, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (524, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (525, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (526, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (527, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (528, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (529, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (530, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (531, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (532, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (533, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (534, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (535, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (536, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (537, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (538, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (539, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (540, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (541, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (542, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (543, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (544, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (545, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (546, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (547, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (548, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (549, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (550, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (551, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (552, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (553, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (554, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (555, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (556, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (557, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (558, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (559, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (560, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (561, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (562, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (563, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (564, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (565, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (566, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (567, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (568, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (569, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (570, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (571, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (572, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (573, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (574, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (575, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (576, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (577, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (578, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (579, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (580, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (581, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (582, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (583, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (584, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (585, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (586, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (587, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (588, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (589, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (590, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (591, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (592, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (593, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (594, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (595, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (596, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (597, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (598, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (599, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (600, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (601, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (602, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (603, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (604, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (605, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (606, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (607, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (608, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (609, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (610, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (611, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (612, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (613, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (614, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (615, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (616, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (617, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (618, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (619, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (620, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (621, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (622, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (623, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (624, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (625, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (626, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# ...
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (928, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (929, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (930, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (931, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (932, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (933, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (934, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (935, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (936, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (937, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (938, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (939, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (940, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (941, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (942, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (943, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (944, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (945, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (946, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (947, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (948, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (949, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (950, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (951, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (952, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (953, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (954, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (955, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (956, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (957, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (958, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (959, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (960, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (961, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (962, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (963, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (964, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (965, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (966, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (967, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (968, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (969, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (970, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (971, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (972, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (973, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (974, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (975, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (976, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (977, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (978, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (979, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (980, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (981, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (982, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (983, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (984, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (985, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (986, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (987, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (988, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (989, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (990, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (991, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (992, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (993, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (994, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (995, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (996, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (997, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (998, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^
#
# Error inserting data into carrentalratings: invalid input syntax for type numeric: ""
# LINE 1: ... value_for_money) VALUES (999, 0, '', 0, 0, 0, 0, '', '', 0)
#                                                              ^

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM carrentalratings LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, Decimal('7.7'), 'Very good', Decimal('8.3'), Decimal('8.1'), Decimal('9.0'), Decimal('7.8'), Decimal('7.2'), Decimal('6.6'), Decimal('7.7'))
# (2, Decimal('7.7'), 'Very good', Decimal('8.3'), Decimal('8.1'), Decimal('9.0'), Decimal('7.8'), Decimal('7.2'), Decimal('6.6'), Decimal('7.7'))
# (3, Decimal('7.7'), 'Very good', Decimal('8.3'), Decimal('8.1'), Decimal('9.0'), Decimal('7.8'), Decimal('7.2'), Decimal('6.6'), Decimal('7.7'))
# (4, Decimal('7.7'), 'Very good', Decimal('8.3'), Decimal('8.1'), Decimal('9.0'), Decimal('7.8'), Decimal('7.2'), Decimal('6.6'), Decimal('7.7'))
# (5, Decimal('7.7'), 'Very good', Decimal('8.3'), Decimal('8.1'), Decimal('9.0'), Decimal('7.8'), Decimal('7.2'), Decimal('6.6'), Decimal('7.7'))

# %%
# Function to insert data into the rentalcompany table with incremental ID
def insert_rentalcompany_with_id(rentalcompany_id, name, address, location_type):
    try:
        cur.execute(
            "INSERT INTO rentalcompany (rentalcompany_id, name, address, location_type) VALUES (%s, %s, %s, %s)",
            (rentalcompany_id, name, address, location_type)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into rentalcompany: {e}")
        conn.rollback()

# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    rentalcompany_id = 1  # Start ID from 1
    inserted_rental_companies = set()  # To keep track of inserted rental companies

    for row in reader:
        # Extract data from the CSV file
        name = row['supplier_name']
        address = row['supplier_address']
        location_type = row['supplier_loction_type']

        # Check if the rental company is not already inserted
        if name not in inserted_rental_companies:
            # Insert data into rentalcompany with incremental ID
            insert_rentalcompany_with_id(rentalcompany_id, name, address, location_type)
            
            inserted_rental_companies.add(name)  # Add the name to the set of inserted companies
            rentalcompany_id += 1  # Increment ID for the next rental company

# %%
# Function to insert data into the carinfo table
def insert_carinfo(carinfo_id, product_name, type, seats, transmission, rentalcompany_id):
    try:
        cur.execute(
            "INSERT INTO carinfo (carinfo_id, product_name, type, seats, transmission, rentalcompany_id) VALUES (%s, %s, %s, %s, %s, %s)",
            (carinfo_id, product_name, type, seats, transmission, rentalcompany_id)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into carinfo: {e}")
        conn.rollback()

# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    carinfo_id = 1  # Start ID from 1
    rentalcompany_ids = set()  # To store distinct rentalcompany_id values

    for row in reader:
        product_name = row['product_name']
        type = row['group']
        seats = row['seats']
        transmission = row['transmission']
        supplier_name = row['supplier_name']  

        # Check if the rentalcompany_id already exists in the set, if not, assign a new one
        rentalcompany_id = rentalcompany_ids.add(supplier_name) or len(rentalcompany_ids)

        # Insert data into carinfo
        insert_carinfo(carinfo_id, product_name, type, seats, transmission, rentalcompany_id)

        carinfo_id += 1  # Increment ID for the next row

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM carinfo LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, 'Volkswagen Polo', 'Economy', '5', 'Manual', 1)
# (2, 'Citroen C3 Aircross', 'Intermediate', '5', 'Manual', 1)
# (3, 'Fiat 500', 'Mini', '4', 'Manual', 1)
# (4, 'Peugeot 308', 'Compact', '5', 'Manual', 1)
# (5, 'Citroen DS3', 'Compact', '5', 'Manual', 1)

# %%
# Path to CSV file 
csv_file_path =  '/Users/christine/Downloads/germany_hotel_booking.csv'

# %%
# Function to insert data into the customers table
def insert_customer(customer_id, name, email, phone_number, credit_card):
    try:
        cur.execute(
            "INSERT INTO customers (customer_id, name, email, phone_number, credit_card) VALUES (%s, %s, %s, %s, %s)",
            (customer_id, name, email, phone_number, credit_card)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into customers: {e}")
        conn.rollback()

# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    customer_id = 1  # Start ID from 1

    for row in reader:
        name = row['name']
        email = row['email']
        phone_number = row['phone-number']
        credit_card = row['credit_card']

        # Insert data into customers
        insert_customer(customer_id, name, email, phone_number, credit_card)

        customer_id += 1  # Increment ID for the next row

# %%
# Function to insert data into the bookingchannel table
def insert_bookingchannel(bookingchannel_id, distribution_channel, agent, company):
    try:
        cur.execute(
            "INSERT INTO bookingchannel (bookingchannel_id, distribution_channel, agent, company) VALUES (%s, %s, %s, %s)",
            (bookingchannel_id, distribution_channel or None, agent or None, company or None)  # Use None for missing values
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into bookingchannel: {e}")
        conn.rollback()

# Open the new CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    bookingchannel_id = 1  # Start ID from 1
    distinct_channels = set()  # To store distinct booking channels

    for row in reader:
        distribution_channel = row['distribution_channel']
        agent = row['agent']
        company = row['company']

        # Create a unique identifier for the booking channel based on its attributes
        channel_identifier = f"{distribution_channel}-{agent}-{company}"

        # Check if this booking channel is distinct
        if channel_identifier not in distinct_channels:
            # Insert data into bookingchannel, using None for missing values
            insert_bookingchannel(bookingchannel_id, distribution_channel, agent, company)

            distinct_channels.add(channel_identifier)  # Add it to the set of distinct channels
            bookingchannel_id += 1  # Increment ID for the next distinct channel
# Out:
# Error inserting data into bookingchannel: current transaction is aborted, commands ignored until end of transaction block

# %%
# Function to insert data into the roomaddon table
def insert_roomaddon(roomaddon_id, meal, required_car_parking_spaces, total_of_special_requests):
    try:
        cur.execute(
            "INSERT INTO roomaddon (roomaddon_id, meal, required_car_parking_spaces, total_of_special_requests) VALUES (%s, %s, %s, %s)",
            (roomaddon_id, meal, required_car_parking_spaces, total_of_special_requests)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into roomaddon: {e}")
        conn.rollback()

# Open the new CSV file (if needed) and read data
# Replace 'new_csv_file_path' with the path to your new CSV file
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    roomaddon_id = 1  # Start ID from 1

    for row in reader:
        meal = row['meal']
        required_car_parking_spaces = row['required_car_parking_spaces']
        total_of_special_requests = row['total_of_special_requests']

        # Insert data into roomaddon
        insert_roomaddon(roomaddon_id, meal, required_car_parking_spaces, total_of_special_requests)

        roomaddon_id += 1  # Increment ID for the next row

# %%
# Function to get roomaddon_id based on 'meal' value
def get_roomaddon_id(meal):
    try:
        cur.execute("SELECT roomaddon_id FROM roomaddon WHERE meal = %s", (meal,))
        result = cur.fetchone()
        return result[0] if result else None
    except Exception as e:
        print(f"Error fetching roomaddon_id for meal {meal}: {e}")
        return None

# Function to insert data into the roomtype table
def insert_roomtype(roomtype_id, room_type, adults, children, babies, roomaddon_id):
    try:
        cur.execute(
            "INSERT INTO roomtype (roomtype_id, room_type, adults, children, babies, roomaddon_id) VALUES (%s, %s, %s, %s, %s, %s)",
            (roomtype_id, room_type, adults, children, babies, roomaddon_id)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into roomtype: {e}")
        conn.rollback()

# Open the new CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    roomtype_id = 1  # Start ID from 1

    for row in reader:
        room_type = row['reserved_room_type']
        adults = row['adults']
        children = row['children']
        babies = row['babies']
        meal = row['meal']  # Assuming 'meal' corresponds to 'roomaddon' in 'roomaddon' table

        # Get the corresponding 'roomaddon_id' based on 'meal'
        roomaddon_id = get_roomaddon_id(meal)

        if roomaddon_id is not None:
            # Insert data into roomtype
            insert_roomtype(roomtype_id, room_type, adults, children, babies, roomaddon_id)

            roomtype_id += 1  # Increment ID for the next row
        else:
            print(f"roomaddon_id not found for meal: {meal}")

# %%
# Function to fetch customer_id based on customer_name
def fetch_customer_id(customer_name):
    try:
        cur.execute("SELECT customer_id FROM customers WHERE name = %s", (customer_name,))
        result = cur.fetchone()
        return result[0] if result else None
    except Exception as e:
        print(f"Error fetching customer_id for customer_name {customer_name}: {e}")
        return None

# Function to fetch roomtype_id based on reserved_room_type
def fetch_roomtype_id(reserved_room_type):
    try:
        cur.execute("SELECT roomtype_id FROM roomtype WHERE room_type = %s", (reserved_room_type,))
        result = cur.fetchone()
        return result[0] if result else None
    except Exception as e:
        print(f"Error fetching roomtype_id for reserved_room_type {reserved_room_type}: {e}")
        return None

# Function to fetch bookingchannel_id based on distribution_channel
def fetch_bookingchannel_id(distribution_channel):
    try:
        cur.execute("SELECT bookingchannel_id FROM bookingchannel WHERE distribution_channel = %s", (distribution_channel,))
        result = cur.fetchone()
        return result[0] if result else None
    except Exception as e:
        print(f"Error fetching bookingchannel_id for distribution_channel {distribution_channel}: {e}")
        return None

# %%
# Function to insert data into the hotelrate table
def insert_hotelrate(hotelrate_id, name, arrival_month, arrival_day, price, customer_name, reserved_room_type, distribution_channel):
    try:
        # Fetch the foreign key IDs using the fetch functions
        customer_id = fetch_customer_id(customer_name)
        roomtype_id = fetch_roomtype_id(reserved_room_type)
        bookingchannel_id = fetch_bookingchannel_id(distribution_channel)
        
        # Map month names to numeric values
        month_mapping = {
            'January': 1,
            'February': 2,
            'March': 3,
            'April': 4,
            'May': 5,
            'June': 6,
            'July': 7,
            'August': 8,
            'September': 9,
            'October': 10,
            'November': 11,
            'December': 12
        }
        
        # Convert arrival_month to an integer using the mapping
        arrival_month = month_mapping.get(arrival_month, None)
        
        # Ensure that arrival_month is not None
        if arrival_month is None:
            raise ValueError(f"Invalid month name: {arrival_month}")
        
        # Convert arrival_day to an integer
        arrival_day = int(arrival_day)
        
        cur.execute(
            "INSERT INTO hotelrate (hotelrate_id, name, arrival_month, arrival_day, price, customer_id, roomtype_id, bookingchannel_id) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)",
            (hotelrate_id, name, arrival_month, arrival_day, price, customer_id, roomtype_id, bookingchannel_id)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into hotelrate: {e}")
        conn.rollback()

# Open the CSV file and read data
with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    hotelrate_id = 1  # Start ID from 1
    for row in reader:
        name ='hotel'
        arrival_month = row['arrival_date_month']
        arrival_day = row['arrival_date_day_of_month']
        price = row['adr']  # Assuming 'adr' in your CSV corresponds to 'price'
        customer_name = row['name']
        reserved_room_type = row['reserved_room_type']
        distribution_channel = row['distribution_channel']

        # Insert data into hotelrate
        insert_hotelrate(hotelrate_id, name, arrival_month, arrival_day, price, customer_name, reserved_room_type, distribution_channel)

        hotelrate_id += 1  # Increment ID for the next row

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM hotelrate LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, 'hotel', 7, 3, Decimal('110.70'), 1, None, 3, None)
# (2, 'hotel', 7, 3, Decimal('90.95'), 2, None, 2, None)
# (3, 'hotel', 7, 5, Decimal('89.00'), 3, None, 3, None)
# (4, 'hotel', 7, 5, Decimal('101.00'), 4, None, 3, None)
# (5, 'hotel', 7, 11, Decimal('144.90'), 5, None, 3, None)

# %%
# Function to insert data into the hotelcancellations table
def insert_hotelcancellation(hotelcancellation_id, booking_changes, room_type, reservation_status):
    try:
        # Fetch the foreign key ID for roomtype
        roomtype_id = fetch_roomtype_id(room_type)
        
        cur.execute(
            "INSERT INTO hotelcancellations (hotelcancellation_id, booking_changes, roomtype_id, reservation_status) VALUES (%s, %s, %s, %s)",
            (hotelcancellation_id, booking_changes, roomtype_id, reservation_status)
        )
        conn.commit()
    except Exception as e:
        print(f"Error inserting data into hotelcancellations: {e}")
        conn.rollback()

with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)

    hotelcancellation_id = 1  # Start ID from 1
    for row in reader:
        booking_changes = row['booking_changes']
        room_type = row['reserved_room_type']
        reservation_status = row['reservation_status']

        # Insert data into hotelcancellations
        insert_hotelcancellation(hotelcancellation_id, booking_changes, room_type, reservation_status)

        hotelcancellation_id += 1  # Increment ID for the next row

# %%
def fetch_data(query):
    try:
        cur.execute(query)
        return cur.fetchall()
    except Exception as e:
        print(f"Error fetching data: {e}")
        return []

# Fetch the first 5 rows from carrentalprice
first_five_rows = fetch_data("SELECT * FROM hotelcancellations LIMIT 5")

# Display the results
for row in first_five_rows:
    print(row)
# Out:
# (1, 0, None, 'Check-Out')
# (2, 0, None, 'Check-Out')
# (3, 0, None, 'Check-Out')
# (4, 0, None, 'Check-Out')
# (5, 1, None, 'Check-Out')

# %%
# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
